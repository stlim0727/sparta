# %% [markdown]
# <a href="https://colab.research.google.com/github/stlim0727/sparta/blob/main/JB_%EC%A0%84%EB%9E%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://coding-kindergarten.tistory.com/124

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# !pip install finance-datareader

# %%
import FinanceDataReader as fdr

# 차트 설정
config = {'title':'fdr.chart.config()를 사용하여 설정을 한번에 지정할 수 있습니다', 
          'width': 1200, 
          'height': 500,
          'volume': True,
}

fdr.chart.config(config=config)

since2023 = '2023-01-01'
since2020 = '2020'

# 삼성전자 주가 데이터 가져오기 (2020년 1월 1일부터 현재까지)
df_samsung = fdr.DataReader('005930', since2023)
df_ks11 = fdr.DataReader('KS200', since2023)
df_ks11_since2020 = fdr.DataReader('KS200', since2020)

# %% [markdown]
# # 삼성전자

# %%
# 가져온 데이터로 캔들차트 그리기
fdr.chart.plot(df_samsung, title='삼성전자(005930)')
# Out:
#   <div class="bk-root" id="8c3b401d-7f73-4ff8-bf83-de9758f42fe6" data-root-id="5491"></div>

# %%
fdr.chart.plot(df_ks11, title='KOSPI')
# Out:
#   <div class="bk-root" id="6b9acf75-ae98-4e45-a88e-6103c16c7f5e" data-root-id="6132"></div>

# %%
import pandas as pd

item_list = [df_samsung.High, df_ks11.High]

df = pd.concat(item_list, axis=1)
df.columns = ["Samsung", "KOSPI"]

# %%
#  차트 설정
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'nanummyeongjo'
plt.rcParams["figure.figsize"] = (12,5)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams["axes.grid"] = True

# %%
# %%html
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>
# Out:
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>

# %%
rs = df_samsung.High / df_ks11.High
rs.plot(title='Samsung/KOSPI')
# Out:
# <Axes: title={'center': 'Samsung/KOSPI'}, xlabel='Date'>

# %% [markdown]
# # 위기는 기회다! 위기는 지수로부터 판단한다
# ## 3년내 최고점으로부터 50% 하락 시점을 찾아라. 1년간, 50~100% 오를 것이다

# %%
df_ks11_since2020["Close"].plot()
# Out:
# <Axes: xlabel='Date'>
